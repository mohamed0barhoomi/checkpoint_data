# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamed0barhoomi/checkpoint_data/blob/main/cifar10_RN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras import models,layers,datasets
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
(x_train,y_train),(x_test,y_test) = datasets.cifar10.load_data()
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step

# %%
x_train,x_test=x_train/255.0,x_test/255.0
print(x_train)
# Out:
# [[[[0.23137255 0.24313725 0.24705882]
#    [0.16862745 0.18039216 0.17647059]
#    [0.19607843 0.18823529 0.16862745]
#    ...
#    [0.61960784 0.51764706 0.42352941]
#    [0.59607843 0.49019608 0.4       ]
#    [0.58039216 0.48627451 0.40392157]]
#
#   [[0.0627451  0.07843137 0.07843137]
#    [0.         0.         0.        ]
#    [0.07058824 0.03137255 0.        ]
#    ...
#    [0.48235294 0.34509804 0.21568627]
#    [0.46666667 0.3254902  0.19607843]
#    [0.47843137 0.34117647 0.22352941]]
#
#   [[0.09803922 0.09411765 0.08235294]
#    [0.0627451  0.02745098 0.        ]
#    [0.19215686 0.10588235 0.03137255]
#    ...
#    [0.4627451  0.32941176 0.19607843]
#    [0.47058824 0.32941176 0.19607843]
#    [0.42745098 0.28627451 0.16470588]]
#
#   ...
#
#   [[0.81568627 0.66666667 0.37647059]
#    [0.78823529 0.6        0.13333333]
#    [0.77647059 0.63137255 0.10196078]
#    ...
#    [0.62745098 0.52156863 0.2745098 ]
#    [0.21960784 0.12156863 0.02745098]
# ...

# %%
target_name=['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
print(x_train.shape)
# Out:
# (50000, 32, 32, 3)

# %%
plt.figure(figsize=(8,8))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i])
    plt.xlabel(target_name[y_train[i][0]])

plt.show()

# %%
plt.figure(figsize=(8,8))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i])
    plt.xlabel(target_name[y_test[i][0]])

plt.show()

# %%
#model with dropout :
#model with dropout :
#model with dropout :
#model with dropout :
#model with dropout :
#model with dropout :
#model with dropout :
#model with dropout :
#model with dropout :

# %%
model=models.Sequential()
model.add(layers.Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)))
model.add(layers.MaxPooling2D(pool_size=(2,2)))
model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2,2)))
model.add(layers.Dropout(0.35))
model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2,2)))
model.add(layers.Flatten())
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10,activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 6, 6, 64)       │             0 │
# ...

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history=model.fit(x_train,y_train,epochs=22,batch_size=19,validation_data=(x_test,y_test),validation_split=0.2,verbose=1)
# Out:
# Epoch 1/22
# 2632/2632 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.3342 - loss: 1.7826 - val_accuracy: 0.4764 - val_loss: 1.4452
# Epoch 2/22
# 2632/2632 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.4693 - loss: 1.4747 - val_accuracy: 0.5464 - val_loss: 1.2440
# Epoch 3/22
# 2632/2632 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.5142 - loss: 1.3531 - val_accuracy: 0.5890 - val_loss: 1.1698
# Epoch 4/22
# 2632/2632 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.5466 - loss: 1.2829 - val_accuracy: 0.6093 - val_loss: 1.1176
# Epoch 5/22
# 2632/2632 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.5703 - loss: 1.2231 - val_accuracy: 0.6351 - val_loss: 1.0441
# Epoch 6/22
# 2632/2632 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.5848 - loss: 1.1848 - val_accuracy: 0.6460 - val_loss: 1.0139
# Epoch 7/22
# 2632/2632 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6008 - loss: 1.1402 - val_accuracy: 0.6499 - val_loss: 0.9958
# Epoch 8/22
# ...

# %%
test_loss, test_acc = model.evaluate(x_test,y_test,verbose=2)

print(test_acc)
# Out:
# 313/313 - 2s - 7ms/step - accuracy: 0.7145 - loss: 0.8296
# 0.7145000100135803

# %%
plt.figure()
plt.plot(history.history['loss'],label='train_loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend(loc='upper left')
plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid()
plt.show()

# %%
plt.figure()
plt.plot(history.history['accuracy'], label='train_accurcay')
plt.plot(history.history['val_accuracy'], label='val_accurcy')
plt.legend(loc='upper left')
plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.grid()
plt.show()

# %%
print(x_test.shape)
pred=model.predict(x_test)
list_pred=np.argmax(pred,axis=1)
nb_erreur=0
plt.figure(figsize=(4,4))
for i in range(100):
    # plt.subplot(2,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    if(target_name[list_pred[i]]!=target_name[y_test[i][0]]):
      nb_erreur+=1
      plt.imshow(x_test[i])
      plt.xlabel("pred_Name:{} \n true_Name:{}".format(target_name[list_pred[i]],target_name[y_test[i][0]]))
      plt.show()
# Out:
# (10000, 32, 32, 3)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
print("procentage derreur : {}%".format(nb_erreur))
# Out:
# procentage derreur : 28%

# %%
#model without Dropout :
#model without Dropout :
#model without Dropout :
#model without Dropout :
#model without Dropout :
#model without Dropout :
#model without Dropout :

# %%
new_model=models.Sequential()
new_model.add(layers.Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)))
new_model.add(layers.MaxPooling2D(pool_size=(2,2)))
new_model.add(layers.Conv2D(64,(3,3),activation='relu'))
new_model.add(layers.MaxPooling2D(pool_size=(2,2)))
new_model.add(layers.Conv2D(64,(3,3),activation='relu'))
new_model.add(layers.MaxPooling2D(pool_size=(2,2)))
new_model.add(layers.Flatten())
new_model.add(layers.Dense(64,activation='relu'))
new_model.add(layers.Dense(10,activation='softmax'))

# %%
new_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
history=new_model.fit(x_train,y_train,epochs=22,batch_size=19,validation_data=(x_test,y_test),validation_split=0.2,verbose=1)
# Out:
# Epoch 1/22
# 2632/2632 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.4350 - loss: 1.5403 - val_accuracy: 0.5212 - val_loss: 1.3323
# Epoch 2/22
# 2632/2632 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.5762 - loss: 1.1921 - val_accuracy: 0.5961 - val_loss: 1.1429
# Epoch 3/22
# 2632/2632 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6307 - loss: 1.0523 - val_accuracy: 0.6296 - val_loss: 1.0539
# Epoch 4/22
# 2632/2632 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6610 - loss: 0.9684 - val_accuracy: 0.6462 - val_loss: 1.0049
# Epoch 5/22
# 2632/2632 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6851 - loss: 0.9029 - val_accuracy: 0.6498 - val_loss: 1.0195
# Epoch 6/22
# 2632/2632 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7024 - loss: 0.8505 - val_accuracy: 0.6783 - val_loss: 0.9279
# Epoch 7/22
# 2632/2632 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7169 - loss: 0.8105 - val_accuracy: 0.6857 - val_loss: 0.9055
# Epoch 8/22
# ...

# %%
plt.figure()
plt.plot(history.history['loss'],label='train_loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend(loc='upper left')
plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid()
plt.show()

# %%
plt.figure()
plt.plot(history.history['accuracy'], label='train_accurcay')
plt.plot(history.history['val_accuracy'], label='val_accurcy')
plt.legend(loc='upper left')
plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.grid()
plt.show()

# %%
print(x_test.shape)
pred=new_model.predict(x_test)
list_pred=np.argmax(pred,axis=1)
nb_erreur=0
plt.figure(figsize=(4,4))
for i in range(100):
    # plt.subplot(2,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    if(target_name[list_pred[i]]!=target_name[y_test[i][0]]):
      nb_erreur+=1
      plt.imshow(x_test[i])
      plt.xlabel("pred_Name:{} \n true_Name:{}".format(target_name[list_pred[i]],target_name[y_test[i][0]]))
      plt.show()
# Out:
# (10000, 32, 32, 3)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
print("procentage derreur : {}%".format(nb_erreur))
# Out:
# procentage derreur : 29%

# %%
modification=ImageDataGenerator(
    rotation_range=15,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
)
modification.fit(x_train)
print("le nauveau shape :",x_train.shape)
# Out:
# le nauveau shape : (50000, 32, 32, 3)

# %%
exemple=(x_train[0]*255).reshape(1,32,32,3)
img_augmenter=modification.flow(exemple,batch_size=1)
plt.figure(figsize=(8,8))
for i in range(15):
    img=next(img_augmenter)[0]
    plt.subplot(5,3,i+1)
    plt.imshow((img).astype("uint8"))
    plt.axis('off')
plt.suptitle("image augmenter")
plt.show()

# %%
model_optimal=models.Sequential()
model_optimal.add(layers.Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)))
model_optimal.add(layers.MaxPooling2D(pool_size=(2,2)))
model_optimal.add(layers.Conv2D(64,(3,3),activation='relu'))
model_optimal.add(layers.MaxPooling2D(pool_size=(2,2)))
# model_optimal.add(layers.Dropout(0.35))
model_optimal.add(layers.Conv2D(64,(3,3),activation='relu'))
model_optimal.add(layers.MaxPooling2D(pool_size=(2,2)))
model_optimal.add(layers.Flatten())
model_optimal.add(layers.Dense(64,activation='relu'))
model_optimal.add(layers.Dropout(0.5))
model_optimal.add(layers.Dense(10,activation='softmax'))

# %%
model_optimal.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history=model_optimal.fit(modification.flow(x_train,y_train,batch_size=20),epochs=50,validation_data=(x_test,y_test),verbose=1)
# Out:
# Epoch 1/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.2801 - loss: 1.8990 - val_accuracy: 0.4048 - val_loss: 1.6212
# Epoch 2/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 37s 15ms/step - accuracy: 0.3982 - loss: 1.6406 - val_accuracy: 0.4910 - val_loss: 1.3847
# Epoch 3/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 36s 14ms/step - accuracy: 0.4532 - loss: 1.5175 - val_accuracy: 0.5576 - val_loss: 1.2472
# Epoch 4/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 36s 14ms/step - accuracy: 0.4852 - loss: 1.4441 - val_accuracy: 0.5824 - val_loss: 1.1653
# Epoch 5/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 35s 14ms/step - accuracy: 0.5073 - loss: 1.3919 - val_accuracy: 0.6018 - val_loss: 1.1115
# Epoch 6/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 35s 14ms/step - accuracy: 0.5261 - loss: 1.3513 - val_accuracy: 0.5816 - val_loss: 1.1668
# Epoch 7/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 36s 14ms/step - accuracy: 0.5390 - loss: 1.3165 - val_accuracy: 0.5830 - val_loss: 1.1644
# Epoch 8/50
# ...

# %%
test_loss, test_acc = model_optimal.evaluate(x_test,y_test,verbose=2)
print(test_acc)
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.7239 - loss: 0.8312
# 0.7239000201225281

# %%
plt.figure()
plt.plot(history.history['loss'],label='train_loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend(loc='upper left')
plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid()
plt.show()

# %%
plt.figure()
plt.plot(history.history['accuracy'], label='train_accurcay')
plt.plot(history.history['val_accuracy'], label='val_accurcy')
plt.legend(loc='upper left')
plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.grid()
plt.show()

# %%
print(x_test.shape)
pred=model_optimal.predict(x_test)
list_pred=np.argmax(pred,axis=1)
nb_erreur=0
plt.figure(figsize=(4,4))
for i in range(100):
    # plt.subplot(2,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    if(target_name[list_pred[i]]!=target_name[y_test[i][0]]):
      nb_erreur+=1
      plt.imshow(x_test[i])
      plt.xlabel("pred_Name:{} \n true_Name:{}".format(target_name[list_pred[i]],target_name[y_test[i][0]]))
plt.show()
# Out:
# (10000, 32, 32, 3)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
print("le nbr derreur : {}%".format(nb_erreur))
# Out:
# le nbr derreur : 27%
